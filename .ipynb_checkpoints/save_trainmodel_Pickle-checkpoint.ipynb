# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from PIL import Image
import h5py
import pickle

#Glasses classification
# Read dataset
path = 'Picture.h5'
file = h5py.File(path,'r+')

# %%
print(file.keys())
# Out:
# <KeysViewHDF5 ['dataset', 'label']>

# %%
X_data = np.array(file["/dataset"]).astype("uint8")
y_data = np.array(file["/label"]).astype("uint8")
file.close()

# %%
y = np.ravel(y_data)

# %%
y.shape
# Out:
# (341,)

# %%
#split the training set and testing set
from sklearn.model_selection import train_test_split
# use 40% of testing
X_train, X_test, y_train, y_test = train_test_split(X_data, y, test_size=0.4,
                                                   random_state=42)

# %%
# Train data
print(X_train.shape)
print(y_train.shape)

# Test data
print(X_test.shape)
print(y_test.shape)
# Out:
# (204, 80000)
# (204,)
# (137, 80000)
# (137,)

# %%
# Use LDA for dimensionality reduction
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=2)
lda.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=2)

# %%
# Transform the training data and test data
X_train = lda.transform(X_train)
X_test = lda.transform(X_test)

# %%
# Use SVM model do training and prediction
from sklearn import svm
from sklearn.metrics import accuracy_score

# Create SVM classifier
clf = svm.SVC(kernel='linear', C=15, gamma="scale" , probability=True)

# Train the model using training set
model = clf.fit(X_train, y_train)

# Make Predict for the testing set.
svm_pred = clf.predict(X_test)
print("Testing Accuracy: ", accuracy_score(y_test,svm_pred))
# Out:
# Testing Accuracy:  0.8467153284671532

# %%
# save the model into img_model.p
pickle.dump(model,open('model_SVM.p','wb'))
print("Pickle is dumped successfully")
# Out:
# Pickle is dumped successfully

# %%
import cv2 as cv
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
img_path='All_images/3_100.jpg'
img=cv.imread(img_path)

img_resized = cv.resize(img, (400, 200))
img_gray = cv.cvtColor(img_resized, cv.COLOR_BGR2GRAY)
l=img_gray.flatten().reshape(1,-1)

plt.imshow(img_gray)

# %%
l = lda.transform(l)

# %%
probability=clf.predict_proba(l)
Categories=['BSN','Maybank','Public Bank']

probability
# Out:
# array([[0.02554093, 0.01269616, 0.96176291]])

# %%
store_max=[]
for ind,val in enumerate(Categories):
  print(f'{val} = {probability[0][ind]*100}%')
  store_max.append(probability[0][ind]*100)
    

store_max
# Out:
# BSN = 2.5540929446587692%
# Maybank = 1.2696157705291538%
# Public Bank = 96.17629128481207%
# [2.5540929446587692, 1.2696157705291538, 96.17629128481207]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, svm_pred, labels=clf.classes_.tolist()))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.91      0.86        56
#            2       0.74      0.74      0.74        35
#            3       0.97      0.85      0.91        46
#
#     accuracy                           0.85       137
#    macro avg       0.85      0.83      0.84       137
# weighted avg       0.85      0.85      0.85       137

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, svm_pred)


plt.figure(figsize= (5,5))

sns.heatmap(cm, annot=True, fmt='.2f',
           linewidth=0.5, square=True, cmap='Blues_r')

plt.title("Confusion Matrix for SVM\n")
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.show()

# %% [markdown]
# # K-NN

# %%
#split the training set and testing set
from sklearn.model_selection import train_test_split
# use 40% of testing
X_train, X_test, y_train, y_test = train_test_split(X_data, y, test_size=0.4,
                                                   random_state=42)

# %%
# create LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=2) # refer to the n-1 formula, n is the number of classes
lda.fit(X_train, y_train.ravel())
X_train_lda = lda.transform(X_train)
X_test_lda = lda.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=5)
model = knn.fit(X_train_lda, y_train)

knn_pred = knn.predict(X_test_lda)

print("Accuracy : ", accuracy_score(y_test,knn_pred))
# Out:
# Accuracy :  0.8540145985401459

# %%
# save the model into img_model.p
pickle.dump(model,open('model_KNN.p','wb'))
print("Pickle is dumped successfully")
# Out:
# Pickle is dumped successfully

# %%
import cv2 as cv
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
img_path='All_images/3_100.jpg'
img=cv.imread(img_path)

img_resized = cv.resize(img, (400, 200))
img_gray = cv.cvtColor(img_resized, cv.COLOR_BGR2GRAY)
l=img_gray.flatten().reshape(1,-1)

plt.imshow(img_gray)

# %%
test11 = lda.transform(l)
probabi=knn.predict_proba(test11)
Categories=['BSN','Maybank','Public Bank']

probabi
# Out:
# array([[0., 0., 1.]])

# %%
store_max=[]
for ind,val in enumerate(Categories):
  print(f'{val} = {probabi[0][ind]*100}%')
  store_max.append(probabi[0][ind]*100)
    

store_max
# Out:
# BSN = 0.0%
# Maybank = 0.0%
# Public Bank = 100.0%
# [0.0, 0.0, 100.0]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, knn_pred, labels=knn.classes_.tolist()))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.93      0.87        56
#            2       0.79      0.74      0.76        35
#            3       0.97      0.85      0.91        46
#
#     accuracy                           0.85       137
#    macro avg       0.86      0.84      0.85       137
# weighted avg       0.86      0.85      0.85       137

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, knn_pred)


plt.figure(figsize= (5,5))

sns.heatmap(cm, annot=True, fmt='.2f',
           linewidth=0.5, square=True, cmap='Blues_r')

plt.title("Confusion Matrix for KNN\n")
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.show()

# %% [markdown]
# # MLP

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y, test_size=0.4,
                                                   random_state=42)

# %%
# Train data
print(X_train.shape)
print(y_train.shape)

# Test data
print(X_test.shape)
print(y_test.shape)
# Out:
# (204, 80000)
# (204,)
# (137, 80000)
# (137,)

# %%
# Use LDA for dimensionality reduction
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=2)

lda.fit(X_train,y_train)
# Transform the training data and test data
X_train_lda = lda.transform(X_train)
X_test_lda = lda.transform(X_test)

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes = (10), max_iter = 1000)

model = mlp.fit(X_train_lda, y_train)


mlp_pred = mlp.predict(X_test_lda)
print("Testing Accuracy:", accuracy_score(y_test, mlp_pred))
# Out:
# Testing Accuracy: 0.8613138686131386

# %%
import cv2 as cv
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
img_path='All_images/3_100.jpg'
img=cv.imread(img_path)

img_resized = cv.resize(img, (400, 200))
img_gray = cv.cvtColor(img_resized, cv.COLOR_BGR2GRAY)
l=img_gray.flatten().reshape(1,-1)

plt.imshow(img_gray)

# %%
test11 = lda.transform(l)
probabi=mlp.predict_proba(test11)
Categories=['BSN','Maybank','Public Bank']

probabi
# Out:
# array([[5.97480028e-03, 3.75044410e-04, 9.93650155e-01]])

# %%
store_max=[]
for ind,val in enumerate(Categories):
  print(f'{val} = {probabi[0][ind]*100}%')
  store_max.append(probabi[0][ind]*100)
    

store_max
# Out:
# BSN = 0.5974800281162501%
# Maybank = 0.03750444095926913%
# Public Bank = 99.3650155309245%
# [0.5974800281162501, 0.03750444095926913, 99.3650155309245]

# %%
# save the model into img_model.p
pickle.dump(model,open('model_MLP.p','wb'))
print("Pickle is dumped successfully")
# Out:
# Pickle is dumped successfully

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, mlp_pred, labels=mlp.classes_.tolist()))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88        56
#            2       0.78      0.80      0.79        35
#            3       0.95      0.85      0.90        46
#
#     accuracy                           0.86       137
#    macro avg       0.86      0.85      0.85       137
# weighted avg       0.87      0.86      0.86       137

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, mlp_pred)


plt.figure(figsize= (5,5))

sns.heatmap(cm, annot=True, fmt='.2f',
           linewidth=0.5, square=True, cmap='Blues_r')

plt.title("Confusion Matrix for MLP\n")
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.show()
